# %% [markdown]
# # League Table PROJECT  :  by ( @victorboadum )
#
#
#
# TURNING: **LEAGUE_SCORES** OF: **240_MATCHES** BY: **16_TEAMS** IN: 30_MATCH_DAYS INTO: A **LEAGUE_TABLE**:

# %% [markdown]
# ---------

# %%
data = [['VL Prague', 'VL Kiev', '1', '0', '2', '2'],
 ['VL Amsterdam', 'VL London', '1', '0', '1', '1'],
 ['VL Paris', 'VL Lisbon', '2', '1', '2', '1'],
 ['VL Zagreb', 'VL Ankara', '1', '0', '2', '0'],
 ['VL Bern', 'VL Athens', '0', '0', '1', '1'],
 ['VL Vienna', 'VL Moscow', '0', '1', '0', '1'],
 ['VL Berlin', 'VL Madrid', '1', '0', '2', '1'],
 ['VL Copenhagen', 'VL Rome', '2', '0', '2', '0'],
 ['VL Moscow', 'VL Bern', '2', '0', '3', '0'],
 ['VL Rome', 'VL Paris', '0', '1', '0', '1'],
 ['VL Madrid', 'VL Amsterdam', '1', '0', '2', '1'],
 ['VL Ankara', 'VL Prague', '0', '0', '0', '0'],
 ['VL Kiev', 'VL Berlin', '0', '1', '2', '1'],
 ['VL London', 'VL Copenhagen', '2', '0', '4', '0'],
 ['VL Athens', 'VL Zagreb', '0', '0', '0', '0'],
 ['VL Lisbon', 'VL Vienna', '2', '1', '3', '1'],
 ['VL Copenhagen', 'VL Madrid', '0', '0', '2', '0'],
 ['VL Moscow', 'VL Athens', '1', '0', '2', '0'],
 ['VL Bern', 'VL Lisbon', '0', '0', '0', '2'],
 ['VL Prague', 'VL Zagreb', '1', '1', '3', '2'],
 ['VL Vienna', 'VL Rome', '1', '2', '1', '3'],
 ['VL Berlin', 'VL Ankara', '0', '0', '0', '1'],
 ['VL Paris', 'VL London', '0', '0', '1', '2'],
 ['VL Amsterdam', 'VL Kiev', '2', '1', '4', '3'],
 ['VL Madrid', 'VL Paris', '2', '2', '4', '3'],
 ['VL London', 'VL Vienna', '2', '1', '5', '2'],
 ['VL Rome', 'VL Bern', '0', '1', '1', '1'],
 ['VL Athens', 'VL Prague', '0', '1', '0', '1'],
 ['VL Lisbon', 'VL Moscow', '1', '0', '1', '1'],
 ['VL Ankara', 'VL Amsterdam', '0', '0', '1', '0'],
 ['VL Zagreb', 'VL Berlin', '0', '1', '0', '1'],
 ['VL Kiev', 'VL Copenhagen', '0', '0', '0', '2'],
 ['VL Moscow', 'VL Rome', '1', '2', '1', '2'],
 ['VL Bern', 'VL London', '0', '1', '0', '2'],
 ['VL Lisbon', 'VL Athens', '1', '0', '1', '0'],
 ['VL Vienna', 'VL Madrid', '0', '3', '0', '4'],
 ['VL Amsterdam', 'VL Zagreb', '1', '0', '2', '0'],
 ['VL Paris', 'VL Kiev', '2', '0', '2', '0'],
 ['VL Berlin', 'VL Prague', '1', '1', '1', '1'],
 ['VL Copenhagen', 'VL Ankara', '1', '0', '1', '1'],
 ['VL Rome', 'VL Lisbon', '1', '0', '1', '2'],
 ['VL Madrid', 'VL Bern', '1', '0', '2', '0'],
 ['VL Ankara', 'VL Paris', '0', '1', '0', '2'],
 ['VL Zagreb', 'VL Copenhagen', '0', '0', '1', '0'],
 ['VL Kiev', 'VL Vienna', '1', '1', '2', '1'],
 ['VL Athens', 'VL Berlin', '0', '1', '1', '1'],
 ['VL London', 'VL Moscow', '1', '1', '2', '4'],
 ['VL Prague', 'VL Amsterdam', '0', '1', '0', '2'],
 ['VL Rome', 'VL Athens', '3', '0', '3', '0'],
 ['VL Moscow', 'VL Madrid', '1', '0', '2', '0'],
 ['VL Copenhagen', 'VL Prague', '1', '2', '1', '2'],
 ['VL Amsterdam', 'VL Berlin', '2', '1', '2', '1'],
 ['VL Bern', 'VL Kiev', '0', '0', '1', '0'],
 ['VL Lisbon', 'VL London', '3', '1', '4', '2'],
 ['VL Vienna', 'VL Ankara', '1', '1', '1', '3'],
 ['VL Paris', 'VL Zagreb', '0', '0', '1', '0'],
 ['VL Madrid', 'VL Lisbon', '2', '1', '5', '1'],
 ['VL Kiev', 'VL Moscow', '0', '0', '0', '0'],
 ['VL Berlin', 'VL Copenhagen', '2', '1', '4', '2'],
 ['VL Ankara', 'VL Bern', '0', '0', '1', '1'],
 ['VL London', 'VL Rome', '1', '1', '1', '1'],
 ['VL Prague', 'VL Paris', '0', '1', '1', '2'],
 ['VL Zagreb', 'VL Vienna', '0', '1', '2', '1'],
 ['VL Athens', 'VL Amsterdam', '0', '1', '1', '1'],
 ['VL Lisbon', 'VL Kiev', '1', '1', '2', '1'],
 ['VL Bern', 'VL Zagreb', '1', '1', '2', '2'],
 ['VL Rome', 'VL Madrid', '2', '0', '3', '2'],
 ['VL London', 'VL Athens', '1', '0', '2', '1'],
 ['VL Copenhagen', 'VL Amsterdam', '0', '0', '0', '0'],
 ['VL Moscow', 'VL Ankara', '1', '1', '1', '1'],
 ['VL Paris', 'VL Berlin', '1', '2', '1', '2'],
 ['VL Vienna', 'VL Prague', '1', '0', '3', '1'],
 ['VL Athens', 'VL Copenhagen', '2', '1', '2', '2'],
 ['VL Prague', 'VL Bern', '2', '2', '3', '4'],
 ['VL Kiev', 'VL Rome', '0', '0', '0', '2'],
 ['VL Ankara', 'VL Lisbon', '0', '1', '0', '1'],
 ['VL Zagreb', 'VL Moscow', '1', '1', '1', '3'],
 ['VL Madrid', 'VL London', '1', '0', '3', '1'],
 ['VL Berlin', 'VL Vienna', '0', '0', '1', '0'],
 ['VL Amsterdam', 'VL Paris', '1', '1', '4', '2'],
 ['VL Bern', 'VL Berlin', '2', '0', '2', '1'],
 ['VL Moscow', 'VL Prague', '2', '0', '4', '0'],
 ['VL Vienna', 'VL Amsterdam', '1', '2', '1', '4'],
 ['VL Madrid', 'VL Athens', '1', '1', '1', '1'],
 ['VL Rome', 'VL Ankara', '3', '0', '3', '2'],
 ['VL London', 'VL Kiev', '1', '3', '3', '4'],
 ['VL Paris', 'VL Copenhagen', '1', '0', '2', '0'],
 ['VL Lisbon', 'VL Zagreb', '1', '0', '1', '0'],
 ['VL Prague', 'VL Lisbon', '0', '1', '1', '1'],
 ['VL Zagreb', 'VL Rome', '0', '1', '0', '2'],
 ['VL Athens', 'VL Paris', '1', '1', '1', '2'],
 ['VL Berlin', 'VL Moscow', '0', '2', '0', '3'],
 ['VL Amsterdam', 'VL Bern', '1', '1', '2', '1'],
 ['VL Ankara', 'VL London', '0', '1', '0', '4'],
 ['VL Kiev', 'VL Madrid', '0', '0', '2', '1'],
 ['VL Copenhagen', 'VL Vienna', '1', '1', '2', '1'],
 ['VL Bern', 'VL Copenhagen', '1', '0', '3', '1'],
 ['VL London', 'VL Zagreb', '1', '1', '3', '1'],
 ['VL Lisbon', 'VL Berlin', '1', '0', '3', '0'],
 ['VL Kiev', 'VL Athens', '2', '1', '4', '1'],
 ['VL Vienna', 'VL Paris', '2', '1', '2', '1'],
 ['VL Rome', 'VL Prague', '1', '0', '2', '1'],
 ['VL Madrid', 'VL Ankara', '2', '1', '3', '1'],
 ['VL Moscow', 'VL Amsterdam', '0', '0', '1', '1'],
 ['VL Prague', 'VL London', '1', '1', '2', '1'],
 ['VL Amsterdam', 'VL Lisbon', '0', '1', '0', '1'],
 ['VL Paris', 'VL Bern', '1', '1', '1', '2'],
 ['VL Athens', 'VL Vienna', '0', '0', '0', '0'],
 ['VL Ankara', 'VL Kiev', '1', '3', '1', '4'],
 ['VL Copenhagen', 'VL Moscow', '0', '0', '0', '1'],
 ['VL Zagreb', 'VL Madrid', '0', '1', '0', '2'],
 ['VL Berlin', 'VL Rome', '0', '0', '1', '1'],
 ['VL Kiev', 'VL Zagreb', '1', '0', '1', '0'],
 ['VL Moscow', 'VL Paris', '0', '0', '1', '0'],
 ['VL Madrid', 'VL Prague', '0', '0', '1', '0'],
 ['VL Rome', 'VL Amsterdam', '0', '0', '0', '0'],
 ['VL Lisbon', 'VL Copenhagen', '0', '0', '0', '0'],
 ['VL Bern', 'VL Vienna', '1', '1', '1', '1'],
 ['VL Ankara', 'VL Athens', '1', '0', '3', '0'],
 ['VL London', 'VL Berlin', '0', '1', '1', '2'],
 ['VL Athens', 'VL Bern', '1', '1', '2', '1'],
 ['VL Madrid', 'VL Berlin', '0', '1', '1', '1'],
 ['VL Moscow', 'VL Vienna', '3', '0', '3', '0'],
 ['VL Kiev', 'VL Prague', '2', '1', '4', '2'],
 ['VL Ankara', 'VL Zagreb', '0', '1', '0', '2'],
 ['VL London', 'VL Amsterdam', '1', '0', '1', '0'],
 ['VL Rome', 'VL Copenhagen', '1', '3', '2', '4'],
 ['VL Lisbon', 'VL Paris', '1', '0', '4', '0'],
 ['VL Bern', 'VL Moscow', '2', '0', '2', '1'],
 ['VL Amsterdam', 'VL Madrid', '0', '2', '1', '2'],
 ['VL Prague', 'VL Ankara', '1', '3', '2', '4'],
 ['VL Paris', 'VL Rome', '1', '0', '1', '0'],
 ['VL Berlin', 'VL Kiev', '1', '1', '3', '1'],
 ['VL Copenhagen', 'VL London', '2', '1', '2', '1'],
 ['VL Zagreb', 'VL Athens', '0', '0', '0', '0'],
 ['VL Vienna', 'VL Lisbon', '1', '3', '2', '4'],
 ['VL Madrid', 'VL Copenhagen', '1', '0', '2', '0'],
 ['VL Athens', 'VL Moscow', '0', '1', '0', '3'],
 ['VL Lisbon', 'VL Bern', '0', '0', '2', '1'],
 ['VL Zagreb', 'VL Prague', '2', '0', '3', '1'],
 ['VL Rome', 'VL Vienna', '1', '0', '1', '0'],
 ['VL Ankara', 'VL Berlin', '0', '1', '1', '1'],
 ['VL London', 'VL Paris', '3', '0', '4', '0'],
 ['VL Kiev', 'VL Amsterdam', '0', '0', '0', '1'],
 ['VL Paris', 'VL Madrid', '0', '0', '1', '1'],
 ['VL Bern', 'VL Rome', '0', '1', '3', '1'],
 ['VL Prague', 'VL Athens', '1', '3', '2', '4'],
 ['VL Vienna', 'VL London', '0', '2', '2', '2'],
 ['VL Moscow', 'VL Lisbon', '0', '1', '1', '1'],
 ['VL Amsterdam', 'VL Ankara', '0', '1', '0', '1'],
 ['VL Berlin', 'VL Zagreb', '0', '0', '1', '0'],
 ['VL Copenhagen', 'VL Kiev', '0', '0', '0', '0'],
 ['VL Rome', 'VL Moscow', '1', '0', '2', '0'],
 ['VL London', 'VL Bern', '0', '0', '1', '0'],
 ['VL Athens', 'VL Lisbon', '0', '2', '1', '2'],
 ['VL Madrid', 'VL Vienna', '2', '0', '4', '0'],
 ['VL Zagreb', 'VL Amsterdam', '3', '1', '4', '1'],
 ['VL Kiev', 'VL Paris', '0', '0', '1', '2'],
 ['VL Prague', 'VL Berlin', '1', '1', '2', '3'],
 ['VL Ankara', 'VL Copenhagen', '0', '0', '2', '0'],
 ['VL Bern', 'VL Madrid', '0', '0', '0', '0'],
 ['VL Paris', 'VL Ankara', '1', '0', '1', '0'],
 ['VL Lisbon', 'VL Rome', '0', '0', '0', '0'],
 ['VL Copenhagen', 'VL Zagreb', '1', '0', '1', '1'],
 ['VL Vienna', 'VL Kiev', '0', '0', '0', '0'],
 ['VL Berlin', 'VL Athens', '1', '0', '2', '0'],
 ['VL Moscow', 'VL London', '0', '2', '0', '2'],
 ['VL Amsterdam', 'VL Prague', '1', '0', '2', '0'],
 ['VL Athens', 'VL Rome', '0', '1', '1', '2'],
 ['VL Madrid', 'VL Moscow', '1', '0', '1', '2'],
 ['VL Prague', 'VL Copenhagen', '1', '1', '3', '1'],
 ['VL Berlin', 'VL Amsterdam', '0', '0', '1', '1'],
 ['VL Kiev', 'VL Bern', '0', '0', '0', '1'],
 ['VL London', 'VL Lisbon', '1', '0', '1', '1'],
 ['VL Ankara', 'VL Vienna', '1', '1', '1', '2'],
 ['VL Zagreb', 'VL Paris', '1', '0', '2', '0'],
 ['VL Moscow', 'VL Kiev', '1', '1', '1', '1'],
 ['VL Lisbon', 'VL Madrid', '0', '0', '1', '2'],
 ['VL Bern', 'VL Ankara', '0', '1', '0', '1'],
 ['VL Copenhagen', 'VL Berlin', '0', '0', '0', '0'],
 ['VL Rome', 'VL London', '1', '2', '1', '4'],
 ['VL Amsterdam', 'VL Athens', '1', '0', '4', '0'],
 ['VL Paris', 'VL Prague', '1', '1', '3', '2'],
 ['VL Vienna', 'VL Zagreb', '0', '2', '0', '2'],
 ['VL Zagreb', 'VL Bern', '1', '1', '3', '1'],
 ['VL Madrid', 'VL Rome', '1', '0', '2', '1'],
 ['VL Athens', 'VL London', '1', '1', '1', '2'],
 ['VL Amsterdam', 'VL Copenhagen', '1', '1', '2', '1'],
 ['VL Ankara', 'VL Moscow', '0', '2', '0', '3'],
 ['VL Berlin', 'VL Paris', '0', '1', '0', '1'],
 ['VL Prague', 'VL Vienna', '3', '1', '4', '2'],
 ['VL Kiev', 'VL Lisbon', '0', '2', '1', '2'],
 ['VL Moscow', 'VL Zagreb', '0', '0', '0', '0'],
 ['VL Bern', 'VL Prague', '0', '0', '0', '0'],
 ['VL Rome', 'VL Kiev', '1', '1', '1', '2'],
 ['VL Copenhagen', 'VL Athens', '2', '2', '2', '2'],
 ['VL London', 'VL Madrid', '0', '0', '0', '1'],
 ['VL Vienna', 'VL Berlin', '0', '0', '0', '0'],
 ['VL Paris', 'VL Amsterdam', '1', '1', '1', '2'],
 ['VL Lisbon', 'VL Ankara', '1', '0', '3', '0'],
 ['VL Berlin', 'VL Bern', '2', '0', '3', '0'],
 ['VL Prague', 'VL Moscow', '2', '1', '2', '2'],
 ['VL Amsterdam', 'VL Vienna', '1', '0', '1', '0'],
 ['VL Athens', 'VL Madrid', '0', '0', '0', '0'],
 ['VL Ankara', 'VL Rome', '3', '0', '3', '1'],
 ['VL Kiev', 'VL London', '0', '1', '1', '2'],
 ['VL Copenhagen', 'VL Paris', '1', '1', '1', '1'],
 ['VL Zagreb', 'VL Lisbon', '0', '0', '2', '0'],
 ['VL Lisbon', 'VL Prague', '0', '1', '3', '1'],
 ['VL Rome', 'VL Zagreb', '0', '2', '1', '2'],
 ['VL Paris', 'VL Athens', '2', '0', '2', '1'],
 ['VL London', 'VL Ankara', '1', '0', '2', '0'],
 ['VL Bern', 'VL Amsterdam', '0', '1', '0', '2'],
 ['VL Madrid', 'VL Kiev', '1', '2', '2', '2'],
 ['VL Vienna', 'VL Copenhagen', '1', '0', '2', '0'],
 ['VL Moscow', 'VL Berlin', '1', '1', '1', '2'],
 ['VL Copenhagen', 'VL Bern', '0', '0', '0', '0'],
 ['VL Zagreb', 'VL London', '0', '0', '0', '3'],
 ['VL Berlin', 'VL Lisbon', '1', '1', '3', '1'],
 ['VL Athens', 'VL Kiev', '2', '2', '4', '2'],
 ['VL Paris', 'VL Vienna', '0', '1', '1', '1'],
 ['VL Prague', 'VL Rome', '1', '0', '1', '2'],
 ['VL Ankara', 'VL Madrid', '0', '0', '0', '1'],
 ['VL Amsterdam', 'VL Moscow', '1', '0', '1', '1'],
 ['VL London', 'VL Prague', '1', '0', '2', '0'],
 ['VL Lisbon', 'VL Amsterdam', '0', '0', '1', '1'],
 ['VL Bern', 'VL Paris', '0', '0', '0', '0'],
 ['VL Moscow', 'VL Copenhagen', '0', '0', '1', '0'],
 ['VL Kiev', 'VL Ankara', '1', '1', '3', '2'],
 ['VL Vienna', 'VL Athens', '0', '1', '0', '1'],
 ['VL Madrid', 'VL Zagreb', '2', '0', '4', '0'],
 ['VL Rome', 'VL Berlin', '2', '0', '4', '1'],
 ['VL Zagreb', 'VL Kiev', '2', '0', '5', '0'],
 ['VL Paris', 'VL Moscow', '0', '0', '1', '0'],
 ['VL Prague', 'VL Madrid', '0', '2', '0', '4'],
 ['VL Amsterdam', 'VL Rome', '0', '0', '0', '1'],
 ['VL Copenhagen', 'VL Lisbon', '1', '0', '1', '0'],
 ['VL Vienna', 'VL Bern', '0', '0', '0', '0'],
 ['VL Athens', 'VL Ankara', '1', '0', '1', '1'],
 ['VL Berlin', 'VL London', '1', '1', '3', '1']]

# %%
# cleaning 240_matches into 8_matches per match_day

match_days_list = [[]]

ind = 0

for i in data:
    ind += 1
    
    if len(match_days_list[-1]) == 8:   # 8 matches per each match_day
        match_days_list += [[]]
    
    match_days_list[-1] += [i]
    
data = match_days_list

data
# Out:
# [[['VL Prague', 'VL Kiev', '1', '0', '2', '2'],
#   ['VL Amsterdam', 'VL London', '1', '0', '1', '1'],
#   ['VL Paris', 'VL Lisbon', '2', '1', '2', '1'],
#   ['VL Zagreb', 'VL Ankara', '1', '0', '2', '0'],
#   ['VL Bern', 'VL Athens', '0', '0', '1', '1'],
#   ['VL Vienna', 'VL Moscow', '0', '1', '0', '1'],
#   ['VL Berlin', 'VL Madrid', '1', '0', '2', '1'],
#   ['VL Copenhagen', 'VL Rome', '2', '0', '2', '0']],
#  [['VL Moscow', 'VL Bern', '2', '0', '3', '0'],
#   ['VL Rome', 'VL Paris', '0', '1', '0', '1'],
#   ['VL Madrid', 'VL Amsterdam', '1', '0', '2', '1'],
#   ['VL Ankara', 'VL Prague', '0', '0', '0', '0'],
#   ['VL Kiev', 'VL Berlin', '0', '1', '2', '1'],
#   ['VL London', 'VL Copenhagen', '2', '0', '4', '0'],
#   ['VL Athens', 'VL Zagreb', '0', '0', '0', '0'],
#   ['VL Lisbon', 'VL Vienna', '2', '1', '3', '1']],
#  [['VL Copenhagen', 'VL Madrid', '0', '0', '2', '0'],
#   ['VL Moscow', 'VL Athens', '1', '0', '2', '0'],
#   ['VL Bern', 'VL Lisbon', '0', '0', '0', '2'],
# ...

# %%
print(len(data[0]), "matches per day for:", len(data), "match_days")
# Out:
# 8 matches per day for: 30 match_days

# %%
# grabbing the names of all the teams: playing on each match_day

match_day = [['VL Athens', 'VL Lisbon', '0', '2', '2', '2'],
  ['VL London', 'VL Amsterdam', '0', '1', '0', '1'],
  ['VL Vienna', 'VL Paris', '0', '1', '0', '1'],
  ['VL Berlin', 'VL Copenhagen', '1', '0', '1', '1'],
  ['VL Rome', 'VL Ankara', '0', '0', '2', '0'],
  ['VL Prague', 'VL Madrid', '1', '1', '1', '3'],
  ['VL Bern', 'VL Moscow', '0', '0', '0', '0'],
  ['VL Kiev', 'VL Zagreb', '1', '0', '2', '0']]

team_list = []

for a,b,c,d,e,f in match_day:
    team_list += [a]
    
    team_list += [b]
    
team_list
# Out:
# ['VL Athens',
#  'VL Lisbon',
#  'VL London',
#  'VL Amsterdam',
#  'VL Vienna',
#  'VL Paris',
#  'VL Berlin',
#  'VL Copenhagen',
#  'VL Rome',
#  'VL Ankara',
#  'VL Prague',
#  'VL Madrid',
#  'VL Bern',
#  'VL Moscow',
#  'VL Kiev',
#  'VL Zagreb']

# %%
print(len(team_list), ": teams playing on each match_day")
# Out:
# 16 : teams playing on each match_day

# %%
# transforming: scores in strings into integers:
# at the index of: 2, 3, 4, 5

for i in data:
    for j in i:
        j[2] = int(j[2])
        j[3] = int(j[3])
        j[4] = int(j[4])
        j[5] = int(j[5])
    
data
# Out:
# [[['VL Prague', 'VL Kiev', 1, 0, 2, 2],
#   ['VL Amsterdam', 'VL London', 1, 0, 1, 1],
#   ['VL Paris', 'VL Lisbon', 2, 1, 2, 1],
#   ['VL Zagreb', 'VL Ankara', 1, 0, 2, 0],
#   ['VL Bern', 'VL Athens', 0, 0, 1, 1],
#   ['VL Vienna', 'VL Moscow', 0, 1, 0, 1],
#   ['VL Berlin', 'VL Madrid', 1, 0, 2, 1],
#   ['VL Copenhagen', 'VL Rome', 2, 0, 2, 0]],
#  [['VL Moscow', 'VL Bern', 2, 0, 3, 0],
#   ['VL Rome', 'VL Paris', 0, 1, 0, 1],
#   ['VL Madrid', 'VL Amsterdam', 1, 0, 2, 1],
#   ['VL Ankara', 'VL Prague', 0, 0, 0, 0],
#   ['VL Kiev', 'VL Berlin', 0, 1, 2, 1],
#   ['VL London', 'VL Copenhagen', 2, 0, 4, 0],
#   ['VL Athens', 'VL Zagreb', 0, 0, 0, 0],
#   ['VL Lisbon', 'VL Vienna', 2, 1, 3, 1]],
#  [['VL Copenhagen', 'VL Madrid', 0, 0, 2, 0],
#   ['VL Moscow', 'VL Athens', 1, 0, 2, 0],
#   ['VL Bern', 'VL Lisbon', 0, 0, 0, 2],
#   ['VL Prague', 'VL Zagreb', 1, 1, 3, 2],
#   ['VL Vienna', 'VL Rome', 1, 2, 1, 3],
#   ['VL Berlin', 'VL Ankara', 0, 0, 0, 1],
# ...

# %%
print(len(data), ": match_days")
# Out:
# 30 : match_days

# %%
# features required by a league_Table:

features = {
    "teams_position" : None,
    "teams_name" : None,
    "no_of_games_played" : 0,
    "no_of_wins" : 0,
    "no_of_draws" : 0,
    "no_of_loss" : 0,
    "goals_for_team" : 0,
    "goals_against_team" : 0,
    "goal_difference" : 0,
    "teams_total_points" : 0,
    "5_previous_scores" : [],
    "5_previous_forms" : [],
    "5_previous_scores_total" : 0,
    "5_previous_forms_total" : 0 }

# %%
# each team shares the same features

statistics = {team:features  for team in team_list}

# %%
# similar features shared by all teams

statistics
# Out:
# {'VL Athens': {'teams_position': None,
#   'teams_name': None,
#   'no_of_games_played': 0,
#   'no_of_wins': 0,
#   'no_of_draws': 0,
#   'no_of_loss': 0,
#   'goals_for_team': 0,
#   'goals_against_team': 0,
#   'goal_difference': 0,
#   'teams_total_points': 0,
#   '5_previous_scores': [],
#   '5_previous_forms': [],
#   '5_previous_scores_total': 0,
#   '5_previous_forms_total': 0},
#  'VL Lisbon': {'teams_position': None,
#   'teams_name': None,
#   'no_of_games_played': 0,
#   'no_of_wins': 0,
#   'no_of_draws': 0,
#   'no_of_loss': 0,
#   'goals_for_team': 0,
#   'goals_against_team': 0,
#   'goal_difference': 0,
#   'teams_total_points': 0,
#   '5_previous_scores': [],
#   '5_previous_forms': [],
#   '5_previous_scores_total': 0,
#   '5_previous_forms_total': 0},
#  'VL London': {'teams_position': None,
#   'teams_name': None,
#   'no_of_games_played': 0,
#   'no_of_wins': 0,
#   'no_of_draws': 0,
#   'no_of_loss': 0,
#   'goals_for_team': 0,
#   'goals_against_team': 0,
# ...

# %%
# similar features shared by all teams

statistics = {'VL Athens': {'teams_position': None,
  'teams_name': None,
  'no_of_games_played': 0,
  'no_of_wins': 0,
  'no_of_draws': 0,
  'no_of_loss': 0,
  'goals_for_team': 0,
  'goals_against_team': 0,
  'goal_difference': 0,
  'teams_total_points': 0,
  '5_previous_scores': [],
  '5_previous_forms': [],
  '5_previous_scores_total': 0,
  '5_previous_forms_total': 0},
 'VL Lisbon': {'teams_position': None,
  'teams_name': None,
  'no_of_games_played': 0,
  'no_of_wins': 0,
  'no_of_draws': 0,
  'no_of_loss': 0,
  'goals_for_team': 0,
  'goals_against_team': 0,
  'goal_difference': 0,
  'teams_total_points': 0,
  '5_previous_scores': [],
  '5_previous_forms': [],
  '5_previous_scores_total': 0,
  '5_previous_forms_total': 0},
 'VL London': {'teams_position': None,
  'teams_name': None,
  'no_of_games_played': 0,
  'no_of_wins': 0,
  'no_of_draws': 0,
  'no_of_loss': 0,
  'goals_for_team': 0,
  'goals_against_team': 0,
  'goal_difference': 0,
  'teams_total_points': 0,
  '5_previous_scores': [],
  '5_previous_forms': [],
  '5_previous_scores_total': 0,
  '5_previous_forms_total': 0},
 'VL Amsterdam': {'teams_position': None,
  'teams_name': None,
  'no_of_games_played': 0,
  'no_of_wins': 0,
  'no_of_draws': 0,
  'no_of_loss': 0,
  'goals_for_team': 0,
  'goals_against_team': 0,
  'goal_difference': 0,
  'teams_total_points': 0,
  '5_previous_scores': [],
  '5_previous_forms': [],
  '5_previous_scores_total': 0,
  '5_previous_forms_total': 0},
 'VL Vienna': {'teams_position': None,
  'teams_name': None,
  'no_of_games_played': 0,
  'no_of_wins': 0,
  'no_of_draws': 0,
  'no_of_loss': 0,
  'goals_for_team': 0,
  'goals_against_team': 0,
  'goal_difference': 0,
  'teams_total_points': 0,
  '5_previous_scores': [],
  '5_previous_forms': [],
  '5_previous_scores_total': 0,
  '5_previous_forms_total': 0},
 'VL Paris': {'teams_position': None,
  'teams_name': None,
  'no_of_games_played': 0,
  'no_of_wins': 0,
  'no_of_draws': 0,
  'no_of_loss': 0,
  'goals_for_team': 0,
  'goals_against_team': 0,
  'goal_difference': 0,
  'teams_total_points': 0,
  '5_previous_scores': [],
  '5_previous_forms': [],
  '5_previous_scores_total': 0,
  '5_previous_forms_total': 0},
 'VL Berlin': {'teams_position': None,
  'teams_name': None,
  'no_of_games_played': 0,
  'no_of_wins': 0,
  'no_of_draws': 0,
  'no_of_loss': 0,
  'goals_for_team': 0,
  'goals_against_team': 0,
  'goal_difference': 0,
  'teams_total_points': 0,
  '5_previous_scores': [],
  '5_previous_forms': [],
  '5_previous_scores_total': 0,
  '5_previous_forms_total': 0},
 'VL Copenhagen': {'teams_position': None,
  'teams_name': None,
  'no_of_games_played': 0,
  'no_of_wins': 0,
  'no_of_draws': 0,
  'no_of_loss': 0,
  'goals_for_team': 0,
  'goals_against_team': 0,
  'goal_difference': 0,
  'teams_total_points': 0,
  '5_previous_scores': [],
  '5_previous_forms': [],
  '5_previous_scores_total': 0,
  '5_previous_forms_total': 0},
 'VL Rome': {'teams_position': None,
  'teams_name': None,
  'no_of_games_played': 0,
  'no_of_wins': 0,
  'no_of_draws': 0,
  'no_of_loss': 0,
  'goals_for_team': 0,
  'goals_against_team': 0,
  'goal_difference': 0,
  'teams_total_points': 0,
  '5_previous_scores': [],
  '5_previous_forms': [],
  '5_previous_scores_total': 0,
  '5_previous_forms_total': 0},
 'VL Ankara': {'teams_position': None,
  'teams_name': None,
  'no_of_games_played': 0,
  'no_of_wins': 0,
  'no_of_draws': 0,
  'no_of_loss': 0,
  'goals_for_team': 0,
  'goals_against_team': 0,
  'goal_difference': 0,
  'teams_total_points': 0,
  '5_previous_scores': [],
  '5_previous_forms': [],
  '5_previous_scores_total': 0,
  '5_previous_forms_total': 0},
 'VL Prague': {'teams_position': None,
  'teams_name': None,
  'no_of_games_played': 0,
  'no_of_wins': 0,
  'no_of_draws': 0,
  'no_of_loss': 0,
  'goals_for_team': 0,
  'goals_against_team': 0,
  'goal_difference': 0,
  'teams_total_points': 0,
  '5_previous_scores': [],
  '5_previous_forms': [],
  '5_previous_scores_total': 0,
  '5_previous_forms_total': 0},
 'VL Madrid': {'teams_position': None,
  'teams_name': None,
  'no_of_games_played': 0,
  'no_of_wins': 0,
  'no_of_draws': 0,
  'no_of_loss': 0,
  'goals_for_team': 0,
  'goals_against_team': 0,
  'goal_difference': 0,
  'teams_total_points': 0,
  '5_previous_scores': [],
  '5_previous_forms': [],
  '5_previous_scores_total': 0,
  '5_previous_forms_total': 0},
 'VL Bern': {'teams_position': None,
  'teams_name': None,
  'no_of_games_played': 0,
  'no_of_wins': 0,
  'no_of_draws': 0,
  'no_of_loss': 0,
  'goals_for_team': 0,
  'goals_against_team': 0,
  'goal_difference': 0,
  'teams_total_points': 0,
  '5_previous_scores': [],
  '5_previous_forms': [],
  '5_previous_scores_total': 0,
  '5_previous_forms_total': 0},
 'VL Moscow': {'teams_position': None,
  'teams_name': None,
  'no_of_games_played': 0,
  'no_of_wins': 0,
  'no_of_draws': 0,
  'no_of_loss': 0,
  'goals_for_team': 0,
  'goals_against_team': 0,
  'goal_difference': 0,
  'teams_total_points': 0,
  '5_previous_scores': [],
  '5_previous_forms': [],
  '5_previous_scores_total': 0,
  '5_previous_forms_total': 0},
 'VL Kiev': {'teams_position': None,
  'teams_name': None,
  'no_of_games_played': 0,
  'no_of_wins': 0,
  'no_of_draws': 0,
  'no_of_loss': 0,
  'goals_for_team': 0,
  'goals_against_team': 0,
  'goal_difference': 0,
  'teams_total_points': 0,
  '5_previous_scores': [],
  '5_previous_forms': [],
  '5_previous_scores_total': 0,
  '5_previous_forms_total': 0},
 'VL Zagreb': {'teams_position': None,
  'teams_name': None,
  'no_of_games_played': 0,
  'no_of_wins': 0,
  'no_of_draws': 0,
  'no_of_loss': 0,
  'goals_for_team': 0,
  'goals_against_team': 0,
  'goal_difference': 0,
  'teams_total_points': 0,
  '5_previous_scores': [],
  '5_previous_forms': [],
  '5_previous_scores_total': 0,
  '5_previous_forms_total': 0}}

# %%
# expected result outcome for each match played:

results = {
    
    "home_half_time_score" : 0,
    "away_half_time_score" : 0,
    "home_full_time_score" : 0,
    "away_full_time_score" : 0,
    "half_time_total_score" : 0,
    "full_time_total_score" : 0,
    "half_time_draw_match" : 0,
    "full_time_match_leader" : 0,
    "over/under_1.5" : 0,
    "over/under_2.5" : 0,
    "over/under_3.5" : 0
  
}

# %%
# EACH MATCH PLAYED HAS A:

# a = home_team
# b = away_team
# c = home_team_half_time_score
# d = away_team_half_time_score
# e = home_team_full_time_score
# f = away_team_full_time_score

# %%
def teams_name_for_a(a): # grabs the name of the home_team
    global statistics
    statistics[a]['teams_name'] = a
    #print("done with teams_name_a!!!")
    
    
def teams_name_for_b(b): # grabs the name of the away_team
    global statistics
    statistics[b]['teams_name'] = b
    #print("done with teams_name_b!!!")

# %%
def no_of_wins_for_a(a , e , f): # track the number of wins for the home_team
    global statistics
    
    track_no_of_wins_for_a = 0
    
    if e > f:
        track_no_of_wins_for_a += 1
        
        statistics[a]['no_of_wins'] += track_no_of_wins_for_a
        #print("done with no_of_wins_for_a!!!")
    
    
    


def no_of_wins_for_b(b , e , f ): # track the number of wins for the away_team
    global statistics
    
    track_no_of_wins_for_b = 0
    
    if f > e:
        track_no_of_wins_for_b += 1
        
        statistics[b]['no_of_wins'] += track_no_of_wins_for_b 
        #print("done with no_of_wins_for_b!!!")

# %%
def no_of_draws_for_a(a , e , f ): # track the number of draws made by the home_team
    global statistics
    
    track_no_of_draws_for_a = 0
    if e == f:
        track_no_of_draws_for_a += 1
        
        statistics[a]['no_of_draws'] += track_no_of_draws_for_a
        #print("done with no_of_draws_for_a!!!")
    
    


def no_of_draws_for_b(b , e , f ): # track the number of draws made by the away_team
    global statistics
    
    track_no_of_draws_for_b = 0
    if f == e:
        track_no_of_draws_for_b += 1
        
        statistics[b]['no_of_draws'] += track_no_of_draws_for_b
        #print("done with no_of_draws_for_b!!!")

# %%
def no_of_loss_for_a(a , e , f ): # track the number of loss made by the home_team
    global statistics
    
    track_no_of_loss_for_a = 0
    if e < f:
        track_no_of_loss_for_a += 1
        
        statistics[a]['no_of_loss'] += track_no_of_loss_for_a
        #print("done with no_of_loss_for_a!!!")
    
    


def no_of_loss_for_b(b , e , f ): # track the number of loss made by the away_team
    global statistics
    
    track_no_of_loss_for_b = 0
    if f < e:
        track_no_of_loss_for_b += 1
        
        statistics[b]['no_of_loss'] += track_no_of_loss_for_b
        #print("done with no_of_loss_for_b!!!")

# %%
def goals_for_team_for_a(a , e ): # track the total number of goal scored by the home_team in the season
    global statistics
    
    track_goals_for_team_for_a = 0
    track_goals_for_team_for_a += e
        
    statistics[a]['goals_for_team'] += track_goals_for_team_for_a
    #print("done with goals_for_team_for_a!!!")
    
    


def goals_for_team_for_b(b , f ): # track the total number of goal scored by the away_team in the season
    global statistics
    
    track_goals_for_team_for_b = 0
    track_goals_for_team_for_b += f
        
    statistics[b]['goals_for_team'] += track_goals_for_team_for_b
    #print("done with goals_for_team_for_b!!!")

# %%
def goals_against_team_for_a(a , f ): # track the total number of goal scored against the home_team in the season
    global statistics
    
    track_goals_against_team_for_a = 0
    track_goals_against_team_for_a += f
        
    statistics[a]['goals_against_team'] += track_goals_against_team_for_a
    #print("done with goals_against_team_for_a!!!")
    
    
    


def goals_against_team_for_b(b , e ): # track the total number of goal scored against the away_team in the season
    global statistics
    
    track_goals_against_team_for_b = 0
    track_goals_against_team_for_b += e
        
    statistics[b]['goals_against_team'] += track_goals_against_team_for_b
    #print("done with goals_against_team_for_b!!!")

# %%
def goal_difference_for_a(a ): # track the  goal_difference for the home_team in the season
    global statistics
    
    track_goal_difference_for_a = 0
    track_goal_difference_for_a = statistics[a]['goals_for_team'] - statistics[a]['goals_against_team']
        
    statistics[a]['goal_difference'] = track_goal_difference_for_a
    #print("done with goal_difference_for_a!!!")
    
    


def goal_difference_for_b(b ): # track the goal_difference for the away_team in the season
    global statistics
    
    track_goal_difference_for_b = 0
    track_goal_difference_for_b = statistics[b]['goals_for_team'] - statistics[b]['goals_against_team']
        
    statistics[b]['goal_difference'] = track_goal_difference_for_b 
    #print("done with goal_difference_for_b!!!")

# %%
def teams_total_points_for_a(a , e , f ): # track the total points made by the home_team 
    global statistics
    
    track_teams_total_points_for_a = 0
    if e > f:
        track_teams_total_points_for_a += 3
    elif e == f:
        track_teams_total_points_for_a += 1
    elif e < f:
        track_teams_total_points_for_a += 0
        
    statistics[a]['teams_total_points'] += track_teams_total_points_for_a
    #print("done with teams_total_points_for_a!!!")
    
    
    


def teams_total_points_for_b(b , e , f ): # track the total points made by the away_team 
    global statistics
    
    track_teams_total_points_for_b = 0
    if f > e:
        track_teams_total_points_for_b += 3
    elif f == e:
        track_teams_total_points_for_b += 1
    elif f < e:
        track_teams_total_points_for_b += 0
        
    statistics[b]['teams_total_points'] += track_teams_total_points_for_b
    #print("done with teams_total_points_for_b!!!")

# %%
def previous_5_scores_for_a(a , e , f ): # track all the 5_previous scores: scored by the home_team
    global statistics
    
    track_previous_5_scores_for_a = []
    if len(statistics[a]['5_previous_scores']) == 10:
        del statistics[a]['5_previous_scores'][0]
        del statistics[a]['5_previous_scores'][0]
        
    track_previous_5_scores_for_a += [e]
    track_previous_5_scores_for_a += [f]
        
    statistics[a]['5_previous_scores'] += track_previous_5_scores_for_a
    #print("done with 5_previous_scores_for_a!!!")
    
    
    


def previous_5_scores_for_b(b , e , f ): # track all the 5_previous scores: scored by the away_team
    global statistics
    
    track_previous_5_scores_for_b = []
    if len(statistics[b]['5_previous_scores']) == 10:
        del statistics[b]['5_previous_scores'][0]
        del statistics[b]['5_previous_scores'][0]
    
    track_previous_5_scores_for_b += [e]
    track_previous_5_scores_for_b += [f]
        
    statistics[b]['5_previous_scores'] += track_previous_5_scores_for_b
    #print("done with 5_previous_scores_for_b!!!")

# %%
def previous_5_forms_for_a(a , e , f ): # track all the 5_previous form: of the home_team
    global statistics
    
    track_previous_5_forms_for_a = []
    if len(statistics[a]['5_previous_forms']) == 5:
        del statistics[a]['5_previous_forms'][0]
    
    if e > f:
        track_previous_5_forms_for_a += ["W"] # [20]
    elif e == f:
        track_previous_5_forms_for_a += ["D"] # [10]
    elif e < f:
        track_previous_5_forms_for_a += ["L"] # [0]
        
    statistics[a]['5_previous_forms'] += track_previous_5_forms_for_a
    #print("done with 5_previous_forms_for_a!!!")
    
    
    


def previous_5_forms_for_b(b , e , f ): # track all the 5_previous form: of the away_team
    global statistics
    
    track_previous_5_forms_for_b = []
    if len(statistics[b]['5_previous_forms']) == 5:
        del statistics[b]['5_previous_forms'][0]
    
    if f > e:
        track_previous_5_forms_for_b += ["W"] # [20]
    elif f == e:
        track_previous_5_forms_for_b += ["D"] # [10]
    elif f < e:
        track_previous_5_forms_for_b += ["L"] # [0]
    
    statistics[b]['5_previous_forms'] += track_previous_5_forms_for_b 
    #print("done with 5_previous_forms_for_b!!!")

# %%
def previous_5_scores_total_for_a(a ): # track the total 5_previous scores: scored by the home_team
    global statistics
    
    track_previous_5_scores_total_for_a = 0
    
    for score in statistics[a]['5_previous_scores']:
        track_previous_5_scores_total_for_a += score
        
    statistics[a]['5_previous_scores_total'] = track_previous_5_scores_total_for_a
    #print("done with 5_previous_scores_total_for_a!!!")
    
    


def previous_5_scores_total_for_b(b ): # track the total 5_previous scores: scored by the away_team
    global statistics
    
    track_previous_5_scores_total_for_b = 0
    
    for score in statistics[b]['5_previous_scores']:
        track_previous_5_scores_total_for_b += score
    
    statistics[b]['5_previous_scores_total'] = track_previous_5_scores_total_for_b
    #print("done with 5_previous_scores_total_for_b!!!")

# %%
def previous_5_forms_total_for_a(a ): # track the total 5_previous form: of the home_team
    global statistics
    
    track_previous_5_forms_total_for_a = 0
    
    for score in statistics[a]['5_previous_forms']:
        track_previous_5_forms_total_for_a += score
        
    statistics[a]['5_previous_forms_total'] = track_previous_5_forms_total_for_a
    #print("done with 5_previous_forms_total_for_a!!!")
    
    


def previous_5_forms_total_for_b(b ): # track the total 5_previous form: of the away_team
    global statistics
    
    track_previous_5_forms_total_for_b = 0
    
    for score in statistics[b]['5_previous_forms']:
        track_previous_5_forms_total_for_b += score
    
    statistics[b]['5_previous_forms_total'] = track_previous_5_forms_total_for_b
    #print("done with 5_previous_forms_total_for_b!!!")

# %%
# arrange teams by position: in relation to their track_record/results 


#statistics_list_data = []

#results_list = [[]]

statistics_list = [[]]

league_table = None


def teams_position( a, b, c, d, e, f):
    
    global statistics, league_table, statistics_list, no_of_matches_played, results_list, statistics_list_data
    
    
    teams_name_list = []
    teams_total_points_list = []

    for team in statistics: # grab both: all the teams_name, and their respective total_points
    
        teams_name_list += [team]
        teams_total_points_list += [statistics[team]['teams_total_points']]
    #print("done")
    
    
    
    
    total_points_dict = {}

    for index in range(len(teams_total_points_list)): # casting team_name as key, and points as value into a dictionary
        total_points_dict[teams_name_list[index]] = teams_total_points_list[index]    
    #print("done")
    
    
    
    
    for point in teams_total_points_list: # odering: by keys the teams with large_points to small_points in dictionary 
        for index in range(len(teams_total_points_list)-1):
            if teams_total_points_list[index] < teams_total_points_list[index+1]:
                teams_total_points_list[index],teams_total_points_list[index+1] = teams_total_points_list[index+1],teams_total_points_list[index]
    #print("done")
    
            
            
    teams_position_points = teams_total_points_list # exchanging variable_name
    


    team_position_names = [] # pass teams_name by order of large_points to small_points into a list

    for point in teams_position_points:
        for team_name in total_points_dict:
            if team_name not in team_position_names: 
                if total_points_dict[team_name] == point:
                    team_position_names += [team_name]
    #print("done")
    
    
                
    # eg: team_position_names = ["e", "c", "b", "a", "d", "f"]  
    # eg: teams_position_points = [5, 5, 5, 3, 2, 1]   
    for i in range(len(teams_position_points)-2): # sort out best team out of teams sharing similar points to take a lead
    
        # sort the best team: out of three(3) teams: sharing the similar points, checking their goal_difference 
        if teams_position_points[i] == teams_position_points[i+1] and teams_position_points[i] == teams_position_points[i+2]:
            if statistics[team_position_names[i]]['goal_difference'] < statistics[team_position_names[i+1]]['goal_difference'] and statistics[team_position_names[i]]['goal_difference'] < statistics[team_position_names[i+2]]['goal_difference'] and statistics[team_position_names[i+1]]['goal_difference'] > statistics[team_position_names[i+2]]['goal_difference']:
                team_position_names[i], team_position_names[i+1], team_position_names[i+2] = team_position_names[i], team_position_names[i+2], team_position_names[i+1]
                teams_position_points[i], teams_position_points[i+1], teams_position_points[i+2] = teams_position_points[i], teams_position_points[i+2], teams_position_points[i+1]
            elif statistics[team_position_names[i]]['goal_difference'] < statistics[team_position_names[i+1]]['goal_difference'] and statistics[team_position_names[i]]['goal_difference'] > statistics[team_position_names[i+2]]['goal_difference'] and statistics[team_position_names[i+1]]['goal_difference'] > statistics[team_position_names[i+2]]['goal_difference']:
                team_position_names[i], team_position_names[i+1], team_position_names[i+2] = team_position_names[i+2], team_position_names[i], team_position_names[i+1]
                teams_position_points[i], teams_position_points[i+1], teams_position_points[i+2] = teams_position_points[i+2], teams_position_points[i], teams_position_points[i+1]
            elif statistics[team_position_names[i]]['goal_difference'] > statistics[team_position_names[i+1]]['goal_difference'] and statistics[team_position_names[i]]['goal_difference'] < statistics[team_position_names[i+2]]['goal_difference'] and statistics[team_position_names[i+1]]['goal_difference'] < statistics[team_position_names[i+2]]['goal_difference']:
                team_position_names[i], team_position_names[i+1], team_position_names[i+2] = team_position_names[i+1], team_position_names[i], team_position_names[i+2]
                teams_position_points[i], teams_position_points[i+1], teams_position_points[i+2] = teams_position_points[i+1], teams_position_points[i], teams_position_points[i+2]
            elif statistics[team_position_names[i]]['goal_difference'] > statistics[team_position_names[i+1]]['goal_difference'] and statistics[team_position_names[i]]['goal_difference'] > statistics[team_position_names[i+2]]['goal_difference'] and statistics[team_position_names[i+1]]['goal_difference'] < statistics[team_position_names[i+2]]['goal_difference']:
                team_position_names[i], team_position_names[i+1], team_position_names[i+2] = team_position_names[i+1], team_position_names[i+2], team_position_names[i]
                teams_position_points[i], teams_position_points[i+1], teams_position_points[i+2] = teams_position_points[i+1], teams_position_points[i+2], teams_position_points[i]
            elif statistics[team_position_names[i]]['goal_difference'] > statistics[team_position_names[i+1]]['goal_difference'] and statistics[team_position_names[i]]['goal_difference'] > statistics[team_position_names[i+2]]['goal_difference'] and statistics[team_position_names[i+1]]['goal_difference'] > statistics[team_position_names[i+2]]['goal_difference']:
                team_position_names[i], team_position_names[i+1], team_position_names[i+2] = team_position_names[i+2], team_position_names[i+1], team_position_names[i]
                teams_position_points[i], teams_position_points[i+1], teams_position_points[i+2] = teams_position_points[i+2], teams_position_points[i+1], teams_position_points[i]
        
        # sort the best team: out of two(2) teams: sharing the similar points, checking their goal_difference
        if teams_position_points[i] == teams_position_points[i+1]:
            if statistics[team_position_names[i]]['goal_difference'] < statistics[team_position_names[i+1]]['goal_difference']:
                team_position_names[i], team_position_names[i+1] = team_position_names[i+1], team_position_names[i]
                teams_position_points[i], teams_position_points[i+1] = teams_position_points[i+1], teams_position_points[i]
    #print("done")    
    
    

    # ordered postions:             
    # team_position_names = ["e", "c", "b", "a", "d", "f"]  
    # teams_position_points = [5, 5, 5, 3, 2, 1]: from: large_points to small_points
    track_teams_position = 0

    for index in range(len(team_position_names)): # assigning each team with their calculated position on the league_Table
        track_teams_position += 1
        statistics[team_position_names[index]]['teams_position'] = track_teams_position



    # print_league table:
    # by order of position:
    league_table = [[]]

    for team_name in team_position_names: # create a league_table: by order of first_placed team to the lowest in position
        if len(league_table[-1]) == 14:
            league_table += [[]]
        for feature in statistics[team_name]:
            league_table[-1] += [statistics[team_name][feature]]
            
            
        
    # print: League_Table according to 8matches per each match_day
    if no_of_matches_played % 8 == 0:
        print("**************************************************************"*2)
        league_table_features = []
        for feature in features:
            league_table_features += [feature]
        print(league_table_features)    
        print("**************************************************************"*2)
        for i in league_table:
            print(i)
        print("**************************************************************"*2)
        print("\n")

# %%
no_of_games_played = 0
no_of_matches_played = 0


for match_day in data:
    no_of_games_played += 1

    # STATISTICS:
    for a,b,c,d,e,f in match_day:
        no_of_matches_played += 1
        # a = home_team
        # b = away_team
        # c = home_team_half_time_score
        # d = away_team_half_time_score
        # e = home_team_full_time_score
        # f = away_team_full_time_score
        
        # no. of games played:
        statistics[a]['no_of_games_played'] = no_of_games_played
        statistics[b]['no_of_games_played'] = no_of_games_played
    
        teams_name_for_a(a=a)
        teams_name_for_b(b=b)
        no_of_wins_for_a(a = a, e = e, f = f)
        no_of_wins_for_b(b = b, e = e, f = f)
        no_of_draws_for_a(a = a, e = e, f = f)
        no_of_draws_for_b(b = b, e = e, f = f)
        no_of_loss_for_a(a = a, e = e, f = f)
        no_of_loss_for_b(b = b, e = e, f = f)
        goals_for_team_for_a(a = a, e = e)
        goals_for_team_for_b(b = b, f = f)
        goals_against_team_for_a(a = a, f = f)
        goals_against_team_for_b(b = b, e = e)
        goal_difference_for_a(a = a)
        goal_difference_for_b(b = b)
        teams_total_points_for_a(a = a, e = e, f = f)
        teams_total_points_for_b(b = b, e = e, f = f)
        previous_5_scores_for_a(a = a, e = e, f = f)
        previous_5_scores_for_b(b = b, e = e, f = f)
        previous_5_forms_for_a(a = a, e = e, f = f)
        previous_5_forms_for_b(b = b, e = e, f = f)
        previous_5_scores_total_for_a(a = a)
        previous_5_scores_total_for_b(b = b)
        #previous_5_forms_total_for_a(a = a) # if: "W"=[20] , "D"=[10], "L"=[0] 
        #previous_5_forms_total_for_b(b = b) # if: "W"=[20] , "D"=[10], "L"=[0]
        
        teams_position(a = a, b = b, c = c, d = d, e = e, f = f)
         
    #break
# Out:
# ****************************************************************************************************************************
# ['teams_position', 'teams_name', 'no_of_games_played', 'no_of_wins', 'no_of_draws', 'no_of_loss', 'goals_for_team', 'goals_against_team', 'goal_difference', 'teams_total_points', '5_previous_scores', '5_previous_forms', '5_previous_scores_total', '5_previous_forms_total']
# ****************************************************************************************************************************
# [1, 'VL Paris', 1, 1, 0, 0, 2, 1, 1, 3, [2, 1], ['W'], 3, 0]
# [2, 'VL Copenhagen', 1, 1, 0, 0, 2, 0, 2, 3, [2, 0], ['W'], 2, 0]
# [3, 'VL Berlin', 1, 1, 0, 0, 2, 1, 1, 3, [2, 1], ['W'], 3, 0]
# [4, 'VL Zagreb', 1, 1, 0, 0, 2, 0, 2, 3, [2, 0], ['W'], 2, 0]
# [5, 'VL Moscow', 1, 1, 0, 0, 1, 0, 1, 3, [0, 1], ['W'], 1, 0]
# [6, 'VL Athens', 1, 0, 1, 0, 1, 1, 0, 1, [1, 1], ['D'], 2, 0]
# [7, 'VL London', 1, 0, 1, 0, 1, 1, 0, 1, [1, 1], ['D'], 2, 0]
# ...
